# %% [markdown]
# # Python environment

# %%
! conda list
# Out:
# # packages in environment at /Volumes/SanDisk2TB/Miniconda/miniconda3/envs/RTSP:
# #
# # Name                    Version                   Build  Channel
# appnope                   0.1.0           py38h32f6830_1001    conda-forge
# argon2-cffi               20.1.0           py38h4d0b108_1    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrs                     20.2.0             pyh9f0ad1d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.1                      py_0    conda-forge
# bleach                    3.1.5              pyh9f0ad1d_0    conda-forge
# boost-cpp                 1.72.0               he5d75e3_3    conda-forge
# branca                    0.4.1                      py_0    conda-forge
# brotlipy                  0.7.0           py38h64e0658_1000    conda-forge
# ...
